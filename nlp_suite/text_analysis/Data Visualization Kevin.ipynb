# %%
from text_analysis_kevin import *

# %%
import pickle
import pandas as pd
user_messages_path='../../cached_user_data/Iinden/user_messages.p'
messages=pickle.load(open(user_messages_path, "rb"))

# %%
df = pd.DataFrame()
df['user'] = pd.Series(['Iinded']*len(messages))
df['user_messages'] = pd.Series(messages)
df
# Out:
#          user                                      user_messages
# 0      Iinded  Strange to see no chat about such a popular la...
# 1      Iinded          I mean often times I write Java code like
# 2      Iinded  But I don't know if that kind of code is commo...
# 3      Iinded  The reason it's used like that in Java is a pr...
# 4      Iinded  To use NLTK ah cool, so it's basically just cl...
# ...       ...                                                ...
# 12178  Iinded  im super confused on threading i want to threa...
# 12179  Iinded                how would i thread this for example
# 12180  Iinded           i bet im one of the youngest here. im 13
# 12181  Iinded  a lot and i dont understand i was able to writ...
# 12182  Iinded  have spent over three hours trying to understa...
#
# [12183 rows x 2 columns]

# %%
text_analysis = get_text_analysis(df)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kevinyoussef/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kevinyoussef/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kevinyoussef/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
get_plots(*text_analysis)
